# %% [markdown]
# ```uvx pgcli -h localhost -p 5432 -U postgres -d postgres```
#
# Start postgresql in docker
#
# ```docker compose exec jobmanager ./bin/flink run -py /opt/src/job/flink_hw.py --pyFiles /opt/src -d```
#
# Submit job
#
# ```docker compose exec redpanda rpk topic delete rides```
#
# Delete topic
#
# ```docker compose exec redpanda rpk topic create rides```
#
# Create topic
#
# ```docker compose exec redpanda rpk topic consume green-trips -o -1 --num 1```
#
# Count number of records in Kafka Producer
#
# ```consumer_timeout_ms=5000```
# Timeout for Consumer, not waiting new message

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Reference about window TVF: https://nightlies.apache.org/flink/flink-docs-master/docs/sql/reference/queries/window-tvf/

# %% [markdown]
# ![image.png](attachment:image.png)
